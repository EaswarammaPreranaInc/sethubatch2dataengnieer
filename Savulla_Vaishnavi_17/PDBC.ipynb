# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.4.0-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Downloading mysql_connector_python-9.4.0-cp312-cp312-win_amd64.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/16.4 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/16.4 MB 4.8 MB/s eta 0:00:04
#    ------ --------------------------------- 2.6/16.4 MB 4.4 MB/s eta 0:00:04
#    -------- ------------------------------- 3.4/16.4 MB 4.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.2/16.4 MB 4.2 MB/s eta 0:00:03
#    ------------ --------------------------- 5.0/16.4 MB 4.1 MB/s eta 0:00:03
#    -------------- ------------------------- 5.8/16.4 MB 4.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.8/16.4 MB 4.1 MB/s eta 0:00:03
#    ------------------ --------------------- 7.6/16.4 MB 4.1 MB/s eta 0:00:03
#    -------------------- ------------------- 8.4/16.4 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.2/16.4 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 10.0/16.4 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 10.7/16.4 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.5/16.4 MB 4.0 MB/s eta 0:00:02
#    ------------------------------ --------- 12.3/16.4 MB 4.0 MB/s eta 0:00:02
#    ------------------------------- -------- 13.1/16.4 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 13.9/16.4 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 15.5/16.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.4.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
try:
    con = mysql.connector.connect(host='localhost', user='root', password='Vaishu@8686', database='Employees_c')
    cur=con.cursor()
    cur.execute('Select * from emp')
    print(cur.rowcount)
    for x in cur:
        print(x)
        print(cur.rowcount)
    cur.close()
    con.close()
except mysql.connector.Error as e:
    print("Error in Connection", e)
except mysql.connector.errors.DatabaseError:
    print("start mysql server")
# Out:
# Error in Connection 1045 (28000): Access denied for user 'root'@'localhost' (using password: YES)
