# %%
a= 5

# %%
pi = 3.14

# %%
str = "python"
print(str)
# Out:
# python

# %%
t= True 
print(type(t))
# Out:
# <class 'bool'>

# %%
x =10
print(x)
# Out:
# 10

# %%
print(type(100))
# Out:
# <class 'int'>

# %%
n= "Hello" 
print (n)
# Out:
# Hello

# %%
print( 5+3)
# Out:
# 8

# %%
print (8-2)
# Out:
# 6

# %%
print(4*3)
# Out:
# 12

# %%
print(10/2)
# Out:
# 5.0

# %%
print(11//2)
# Out:
# 5

# %%
print (2**3)
# Out:
# 8

# %%
print(10%3)
# Out:
# 1

# %%
if (5==5) :
    print("true")
# Out:
# true

# %%
if ( 4!=6) :
    print("true")
# Out:
# true

# %%
if (7 >3) :
    print("true")
# Out:
# true

# %%
if 2<9 :
    print("true")
# Out:
# true

# %%
if 5>= 5 :
    print("true")
# Out:
# true

# %%
if 6 <= 7:
    print("true")
# Out:
# true

# %%
a = 10
b=20
print (a+b)
# Out:
# 30

# %%
print (a-b)
# Out:
# -10

# %%
x=15
print (x+5)
# Out:
# 20

# %%
a = "good"
b =" morning"
print(a+b)
# Out:
# good morning

# %%
x =5.0
print (type(x))
# Out:
# <class 'float'>

# %%
x=False
print(x)
# Out:
# False

# %%
x = "DATA"
print(x)
# Out:
# DATA

# %%
a= 0
print(a)
# Out:
# 0

# %%
a =None
print (type(a))
# Out:
# <class 'NoneType'>

# %%
a = 100
print (a*2)
# Out:
# 200

# %%
a = 5
a+=10
print(a)
# Out:
# 15

# %%
a=8
a-=3
print(a)
# Out:
# 5

# %%
a= 24
a*=2
print(a)
# Out:
# 48

# %%
a=24
a/=4
print(a)
# Out:
# 6.0

# %%
a=24
a//=4
print(a)
# Out:
# 6

# %%
a = 20
a%=3
print(a)
# Out:
# 2

# %%
a=10
a**= 2
print(a)
# Out:
# 100

# %%
a = True 
b=False
r=a and b
print (r)
# Out:
# False

# %%
a = True 
b=False
r=a or b
print (r)
# Out:
# True

# %%
a = True 
r = not a
print (r)
# Out:
# False

# %%
print(0 and 1)
# Out:
# 0

# %%
print(0 or 1)
# Out:
# 1

# %%
p = "123"
print (p)
# Out:
# 123

# %%
a= 10
v = float(a)
print (v)
# Out:
# 10.0

# %%
a = 10.0
v = int(a)
print(a)
# Out:
# 10.0

# %%
a= 3+4*2
print(a)
# Out:
# 11

# %%
p =(3+4)*2
print(p)
# Out:
# 14

# %%
a= 7
print(a)
# Out:
# 7

# %%
age = 24
print(age)
# Out:
# 24

# %%
a = 5
print (id(a))
# Out:
# 140722744046632

# %%
a=3.5
print (type(a))
# Out:
# <class 'float'>

# %%
print("5" == 5)
# Out:
# False

# %%
a= 5>2
print(a)
# Out:
# True

# %%
a= 10>=10
print(a)
# Out:
# True

# %%
a= 9.8
print(a)
# Out:
# 9.8

# %%
x = 100
y = x
print(y)
# Out:
# 100

# %%
a=b = c = 3
print (a,b,c)
# Out:
# 3 3 3

# %%
x, y, z = 1, 2, 3
print(x,y,z)
# Out:
# 1 2 3

# %%
a = 5
a=a+1
print(a)
# Out:
# 6

# %%
a =10
a+=5
print(a)
# Out:
# 15

# %%
s ="AI"
print (type(s))
# Out:
# <class 'str'>

# %%
a = 10.00000
print (a)
# Out:
# 10.0

# %%
a = True
b = False
print (a==b)
# Out:
# False

# %%
a=  10
b=10.0
print (a+b)
# Out:
# 20.0

# %%
a = 0.0
if bool(a) :
    print ("true")
else :
    print("false")
# Out:
# false

# %%
a = 10 
print(type(str(a)))
# Out:
# <class 'str'>

# %%
a = "True"
print(type(a))
# Out:
# <class 'str'>

# %%
a = 10.0
print(a*2)
# Out:
# 20.0

# %%
a = 4
b=2
print(a/b)
# Out:
# 2.0

# %%
a = 7 
b = 3
print (a%b)
# Out:
# 1

# %%
a ="coding"
print(a*2)
# Out:
# codingcoding

# %%
a = 3**2
print(a)
# Out:
# 9

# %%
 a ="abc"
 b ="ABC"
if (a==b) :
    print ("true")

# %%
a = 3.0
b =3
if (a==b) :
    print ("true")
# Out:
# true

# %%
a = True
ai = not a
print (ai)
# Out:
# False

# %%
a = 5
a*=3
print(a)
# Out:
# 15

# %%
a =10.0
b = 4.0
print (a/b)
# Out:
# 2.5

# %%
a = 1.5e2 
print(a)
# Out:
# 150.0

# %%
x = 5
x//=2
print(x)
# Out:
# 2

# %%
z = 2 + 3j
print(z.real)
# Out:
# 2.0

# %%
a = 10
b =10
print(a,b)
# Out:
# 10 10

# %%
a = 3
print(a == 3)
# Out:
# True

# %%
new ="None" 
print(type(new))
# Out:
# <class 'str'>

# %%
a = "a"
print(a)
# Out:
# a

# %%
roll_number = 101

# %%
a = 10/3
print (a)
# Out:
# 3.3333333333333335

# %%
a=10//3
print(a)
# Out:
# 3

# %%
a =4
b = a+2*3
print(b)
# Out:
# 10

# %%
a= ""
print(type(a))
# Out:
# <class 'str'>

# %%
a=1
b=0
print(a or b)
# Out:
# 1

# %%
a=1
b=0
print(a and b)
# Out:
# 0

# %%
a = not False
print (a)
# Out:
# True

# %%
print( 6 != 9)
# Out:
# True

# %%
print(10<= 20)
# Out:
# True

# %%
print (2**4)
# Out:
# 16

# %%
num = 123.456
print(num)
# Out:
# 123.456

# %%
a =0.1 + 0.20
print(a)
# Out:
# 0.30000000000000004

# %%
a= 0b10111
print(a)
# Out:
# 23

# %%
a = 2.75
print(round(a))
# Out:
# 3

# %%
new = "42"
print(int(new))
# Out:
# 42

# %%
a = -2.2332
print (abs(a))
# Out:
# 2.2332

# %%
a = True
print(int(a))
# Out:
# 1

# %%
import math

e_value = math.exp(1)
print(e_value)
# Out:
# 2.718281828459045

# %%
a = 0xF
print(a)
# Out:
# 15

# %%
a ="123.45"
print(float(a))
# Out:
# 123.45

# %%
x=y=100
if (x==y) :
    print(x,y)
# Out:
# 100 100

# %%
a = 1.2e3
print(a)
# Out:
# 1200.0

# %%
a = 5
b=10
print(a==b)
# Out:
# False

# %%
a = 10
b=10
print(a is b)
# Out:
# True

# %%
a = 1.232
print(str(a))
# Out:
# 1.232

# %%
a =True
print (int(a))
# Out:
# 1

# %%
a = False 
print(float(a))
# Out:
# 0.0

# %%
# Use bool() on an empty list
print(bool([]))          # Output: False

# Use bool() on a non-empty string
print(bool("Hello"))     # Output: True
# Out:
# False
# True

# %%
print(3.5!=3)
# Out:
# True

# %%
print (10//3)
# Out:
# 3

# %%
a = "new"
print(type(a) is str)
# Out:
# True

# %%
print(4*2+3)
# Out:
# 11

# %%
print(4*(2+3))
# Out:
# 20

# %%
print (5>3 and 2<4)
# Out:
# True

# %%
print(False and True)
# Out:
# False

# %%
a = 5
a-=1
print(a)
# Out:
# 4

# %%
s ="88"
a= int(s)
print(a+12)
# Out:
# 100

# %%
snake_case = 1.233
print (snake_case)
# Out:
# 1.233

# %%
userName = "Alice"
print(userName)
# Out:
# Alice

# %%
a = 1_000_00
print(a)
# Out:
# 100000

# %%
a = True 
print(type(a))
# Out:
# <class 'bool'>

# %%
x= 10
y =x**2
print(y)
# Out:
# 100

# %%
a='3'
i=int(a)
print(i/4)
# Out:
# 0.75

# %%
a = 9.99 
print(round(a))
# Out:
# 10

# %%
a = 10.0
b=int(a)
c = float(b)
print(c)
# Out:
# 10.0

# %%
a = 100
a%=6
print(a)
# Out:
# 4

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
a = 4<=4
print(a)
# Out:
# True

# %%
a =10>5
print(a)
# Out:
# True

# %%
a = 1
b = bool(a)
print(b)
# Out:
# True

# %%
a = 0.0
b = bool(a)
print(b)
# Out:
# False

# %%
print(5+3.0)
# Out:
# 8.0

# %%
a = 2.0
b = 2
print(a+b)
# Out:
# 4.0

# %%
print(9!=10)
# Out:
# True

# %%
sci_float = 5.67e2  # This is 5.67 × 10² = 567.0
print(int(sci_float))
# Out:
# 567
